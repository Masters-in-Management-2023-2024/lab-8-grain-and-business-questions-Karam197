# %% [markdown]
# # Diamond Company Analytics Challenge
#
# **Time:** 35 minutes
#
# **Scenario:** You are the new data analyst at a prestigious diamond company. The CEO has called an urgent meeting and needs answers to critical business questions about the inventory.
#
# **Your Mission:** Analyze the diamond inventory data and provide insights to guide strategic decisions.

# %%
import polars as pl

# Load the diamonds dataset
print("Loading diamonds dataset...")
df = pl.read_csv('https://raw.githubusercontent.com/pycaret/pycaret/master/datasets/diamond.csv')
print("Dataset loaded successfully!")
# Out:
# Loading diamonds dataset...
# Dataset loaded successfully!

# %% [markdown]
# ## Section 1: Initial Inventory Assessment (5 minutes)
#
# The CEO walks in: "Before we dive into specifics, I need to understand what we're working with. Give me the basics about our inventory database."

# %% [markdown]
# ### Question 1: "How extensive is our inventory database?"
#
# The CEO needs to know the scale of data you're analyzing.

# %%
# Your code here:
rows = df.height
cols = df.width
print(f"Total records (rows): {rows}")
print(f"Total attributes (columns): {cols}\n")
# Out:
# Total records (rows): 6000
# Total attributes (columns): 8

# %% [markdown]
# ### Question 2: "What information do we track about each diamond?"
#
# List all the characteristics we record.

# %%
# Your code here:
print(df.columns)
# Out:
# ['Carat Weight', 'Cut', 'Color', 'Clarity', 'Polish', 'Symmetry', 'Report', 'Price']

# %% [markdown]
# ### Question 3: "When I look at one line in this database, what am I looking at?"
#
# Explain in business terms:

# %% [markdown]
# **Your answer:** Each row represents: Each row would represent an individual diamond with all its information recorded based on the characteristics such as cut, color, clarity etc...

# %% [markdown]
# ## Section 2: Strategic Business Questions (20 minutes)
#
# The CEO continues: "Now let's get to the important questions. Our board meeting is tomorrow and I need concrete numbers."

# %% [markdown]
# ### Question 4: "We're considering expanding our storage facilities. How many total carats do we have in inventory? I need to know if our vaults can handle the weight."
#
# Think about what measurement would help answer this.

# %%
total_carats = df["Carat Weight"].sum()
print(f"Total carats in inventory: {total_carats}")
# Out:
# Total carats in inventory: 8007.120000000001

# %% [markdown]
# ### Question 5: "Our new marketing campaign claims we have 'the widest variety of cuts in the industry.' Can you verify this?"
#
# The CEO wants to know about variety, not quantity.

# %%
unique_cuts = df["Cut"].n_unique()
print(f"Number of unique cuts: {unique_cuts}")

print(df["Cut"].unique())
# Out:
# Number of unique cuts: 5
# shape: (5,)
# Series: 'Cut' [str]
# [
# 	"Signature-Ideal"
# 	"Very Good"
# 	"Ideal"
# 	"Good"
# 	"Fair"
# ]

# %% [markdown]
# ### Question 6: "I'm meeting with our insurance company. They need to know our price exposure - what's our most and least valuable diamond?"

# %%
# Your code here:
max_price = df["Price"].max()
min_price = df["Price"].min()

print(f"Most valuable diamond price: ${max_price}")
print(f"Least valuable diamond price: ${min_price}")
# Out:
# Most valuable diamond price: $101561
# Least valuable diamond price: $2184

# %% [markdown]
# ### Question 7: "Which color grades should we focus on in our premium line? I need typical prices across our color spectrum."
#
# The CEO wants to understand pricing patterns.

# %%
# Your code here:
avg_price_by_color = df.group_by("Color").agg(pl.col("Price").mean().round(2))

print(avg_price_by_color)
# Out:
# shape: (6, 2)
# ┌───────┬──────────┐
# │ Color ┆ Price    │
# │ ---   ┆ ---      │
# │ str   ┆ f64      │
# ╞═══════╪══════════╡
# │ F     ┆ 12712.24 │
# │ I     ┆ 8989.64  │
# │ D     ┆ 15255.78 │
# │ E     ┆ 11539.19 │
# │ G     ┆ 12520.05 │
# │ H     ┆ 10487.35 │
# └───────┴──────────┘

# %% [markdown]
# **Reflection:** After analyzing by color, how has your view of the data changed? What does each row in your result represent now?

# %% [markdown]
# **Your answer:** New grain = This will help us identify our pricing strategy based on the color of the diamond. This helps us better understand which colors command a premium in the market.

# %% [markdown]
# ## Section 3: Advanced Strategic Analysis (10 minutes)
#
# The CEO leans forward: "These next questions will shape our strategy for next year."

# %% [markdown]
# ### Question 8: "We're thinking of specializing in certain clarity grades. For our investor deck, I need a complete breakdown showing: how many diamonds we have in each clarity grade, their typical price, and the total carats we're holding for each grade."

# %%
# Your code here:
clarity_summary = df.group_by("Clarity").agg([
    pl.count().alias("count"),
    pl.col("Price").mean().round(2).alias("avg_price"),
    pl.col("Carat Weight").sum().round(2).alias("total_carats")
])

print(clarity_summary)
# Out:
# shape: (7, 4)
# ┌─────────┬───────┬───────────┬──────────────┐
# │ Clarity ┆ count ┆ avg_price ┆ total_carats │
# │ ---     ┆ ---   ┆ ---       ┆ ---          │
# │ str     ┆ u32   ┆ f64       ┆ f64          │
# ╞═════════╪═══════╪═══════════╪══════════════╡
# │ VVS1    ┆ 285   ┆ 16845.68  ┆ 389.43       │
# │ VS1     ┆ 1192  ┆ 13694.11  ┆ 1682.74      │
# │ IF      ┆ 219   ┆ 22105.84  ┆ 316.0        │
# │ SI1     ┆ 2059  ┆ 8018.86   ┆ 2563.69      │
# │ FL      ┆ 4     ┆ 63776.0   ┆ 7.87         │
# │ VVS2    ┆ 666   ┆ 14142.18  ┆ 876.58       │
# │ VS2     ┆ 1575  ┆ 11809.05  ┆ 2170.81      │
# └─────────┴───────┴───────────┴──────────────┘
# /tmp/ipython-input-4117783164.py:3: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
#   pl.count().alias("count"),

# %% [markdown]
# ### Question 9: "My luxury competitor claims they have the best prices for every cut-color combination. Show me our pricing structure across these combinations - I want to see where we're competitive."

# %%
# Your code here:
pricing_structure = df.group_by(["Cut", "Color"]).agg(
    pl.col("Price").mean().round(2).alias("avg_price")
).sort(["Cut", "Color"])

print(pricing_structure)
# Out:
# shape: (30, 3)
# ┌───────────┬───────┬───────────┐
# │ Cut       ┆ Color ┆ avg_price │
# │ ---       ┆ ---   ┆ ---       │
# │ str       ┆ str   ┆ f64       │
# ╞═══════════╪═══════╪═══════════╡
# │ Fair      ┆ D     ┆ 6058.25   │
# │ Fair      ┆ E     ┆ 5370.63   │
# │ Fair      ┆ F     ┆ 6063.63   │
# │ Fair      ┆ G     ┆ 7345.52   │
# │ Fair      ┆ H     ┆ 5908.5    │
# │ …         ┆ …     ┆ …         │
# │ Very Good ┆ E     ┆ 12101.91  │
# │ Very Good ┆ F     ┆ 12413.91  │
# │ Very Good ┆ G     ┆ 12354.01  │
# │ Very Good ┆ H     ┆ 10056.11  │
# │ Very Good ┆ I     ┆ 8930.03   │
# └───────────┴───────┴───────────┘

# %% [markdown]
# ** **Reflection:** How specific is your analysis now? What level of detail does each row represent?

# %% [markdown]
# **Your answer:** New grain = This new grain adds for specificity to our analysis as we can see price differences by cut & color.

# %% [markdown]
# ### Question 10: URGENT - "Our biggest client is interested in purchasing entire inventory segments. They asked: 'Which color-cut combinations represent your highest total inventory value?' Show me the top 5 most valuable inventory segments by total worth, and include how many diamonds are in each segment."
#
# This is critical for tomorrow's negotiation.

# %%
# Your code here:
summary = df.group_by(["Color", "Cut"]).agg([
    pl.col("Price").sum().alias("total_value"),
    pl.len().alias("count")
])

top_5 = summary.sort("total_value", descending=True).head(5)

print(top_5)
# Out:
# shape: (5, 4)
# ┌───────┬───────────┬─────────────┬───────┐
# │ Color ┆ Cut       ┆ total_value ┆ count │
# │ ---   ┆ ---       ┆ ---         ┆ ---   │
# │ str   ┆ str       ┆ i64         ┆ u32   │
# ╞═══════╪═══════════╪═════════════╪═══════╡
# │ G     ┆ Ideal     ┆ 9363514     ┆ 690   │
# │ G     ┆ Very Good ┆ 7140620     ┆ 578   │
# │ F     ┆ Very Good ┆ 5648327     ┆ 455   │
# │ F     ┆ Ideal     ┆ 5346782     ┆ 363   │
# │ H     ┆ Ideal     ┆ 5279687     ┆ 458   │
# └───────┴───────────┴─────────────┴───────┘

# %% [markdown]
# ## Debrief
#
# Congratulations! You've just completed your first day as the diamond company's data analyst.
#
# Remember:
# - CEOs speak in business language, not technical terms
# - Always understand what each row represents before analyzing
# - Business questions contain clues about which operations to use
